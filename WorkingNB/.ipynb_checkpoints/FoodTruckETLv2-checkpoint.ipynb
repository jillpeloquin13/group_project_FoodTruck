# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

# %% [markdown]
# Get the schedule Data for Vancouver

# %%
url = 'http://data.streetfoodapp.com/1.1/schedule/vancouver'

data =  requests.get(url).json()
dfVan = pd.DataFrame.from_dict(data)
dfVan.head()
# Out:
#                                                         metadata  \
# ads            [{'banner': {'identifier': 'frying-pan', 'imag...
# new            [burgerland-smash-up, fisherman-franks, bang-t...
# regions        [{'identifier': 'vancouver', 'name': 'Vancouve...
# arturos-to-go                                                NaN
# babas-house                                                  NaN
#
#                                                          vendors
# ads                                                          NaN
# new                                                          NaN
# regions                                                      NaN
# arturos-to-go  {'description_short': 'Authentic, author gourm...
# babas-house    {'description_short': None, 'identifier': 'bab...

# %%
url = 'http://data.streetfoodapp.com/1.1/schedule/vancouver'
data =  requests.get(url).json()
data = df.vendors.apply(pd.Series)
data.head()
# Out:
#                 0 catering delivery_url  \
# ads           NaN      NaN          NaN
# new           NaN      NaN          NaN
# regions       NaN      NaN          NaN
# arturos-to-go NaN     None         None
# babas-house   NaN     None         None
#
#                                                      description  \
# ads                                                          NaN
# new                                                          NaN
# regions                                                      NaN
# arturos-to-go  Arturo's unique recipes are a fusion of Spanis...
# babas-house    Baba's House specialize in Old Fashion Homemad...
#
#                                                description_short  \
# ads                                                          NaN
# new                                                          NaN
# regions                                                      NaN
# arturos-to-go  Authentic, author gourmet Mexican made with th...
# babas-house                                                 None
#
#                                email          facebook     identifier  \
# ads                              NaN               NaN            NaN
# new                              NaN               NaN            NaN
# regions                          NaN               NaN            NaN
# arturos-to-go    info@arturos2go.com  arturosmexico2go  arturos-to-go
# babas-house    maggierabek@yahoo.com              None    babas-house
#
#                                                           images  \
# ads                                                          NaN
# new                                                          NaN
# regions                                                      NaN
# arturos-to-go  {'logo': 'https://cdn.streetfoodapp.com/images...
# babas-house                                                  NaN
#
#                        instagram  ...  open_updated  \
# ads                          NaN  ...           NaN
# new                          NaN  ...           NaN
# regions                      NaN  ...           NaN
# arturos-to-go         arturos2go  ...  1.633977e+09
# babas-house    babashousekitchen  ...           NaN
#
#                                           payment_methods           phone  \
# ads                                                   NaN             NaN
# new                                                   NaN             NaN
# regions                                               NaN             NaN
# arturos-to-go  [cash, credit_card, debit_card, apple_pay]  (604) 202-4043
# babas-house    [cash, credit_card, debit_card, apple_pay]  (778) 838-5059
#
#                promoted   rank  rating     region  takeout_url  \
# ads                 NaN    NaN     NaN        NaN          NaN
# new                 NaN    NaN     NaN        NaN          NaN
# regions             NaN    NaN     NaN        NaN          NaN
# arturos-to-go      True    8.0  1644.0  vancouver         None
# babas-house       False  113.0    15.0  vancouver         None
#
#                        twitter                    url
# ads                        NaN                    NaN
# new                        NaN                    NaN
# regions                    NaN                    NaN
# arturos-to-go  arturomexico2go         arturos2go.com
# babas-house        BabasHouse2  babashousekitchen.com
#
# [5 rows x 23 columns]

# %%
data2 = data[['description', 'name', 'description_short', 'last']].copy()
data2 = data2.dropna()
data2.head()
# Out:
#                                                      description  \
# arturos-to-go  Arturo's unique recipes are a fusion of Spanis...
# bc-taco        Handmade, always fresh. Tacos, burritos, quesa...
# beavertails    Deliciously famous Canadian pastry. Proudly sa...
# boca-o         BOCA'O is the abbreviation of BOCADO, or BITE ...
# burgerholic    BurgerHolic in Vancouver is specializes in mou...
#
#                                          name  \
# arturos-to-go                arturosmexico2go
# bc-taco                               BC TACO
# beavertails    BeaverTails Mobile (Vancouver)
# boca-o                 Boca'o Spain in a bite
# burgerholic                       BurgerHolic
#
#                                                description_short  \
# arturos-to-go  Authentic, author gourmet Mexican made with th...
# bc-taco        Handmade, always fresh. Tacos, burritos, quesa...
# beavertails    Deliciously famous Canadian pastry. Proudly sa...
# boca-o         Boca'O uses premium Spanish and local ingredie...
# burgerholic    Happy to cater your next event Burgerholic.ca@...
#
#                                                             last
# arturos-to-go  {'time': 1633635000, 'display': 'Howe St & W C...
# bc-taco        {'time': 1633635000, 'display': 'Rocky Point S...
# beavertails    {'time': 1632708000, 'display': 'Richmond Nigh...
# boca-o         {'time': 1633629600, 'display': 'Jonathan Roge...
# burgerholic    {'time': 1633629600, 'display': 'Jonathan Roge...

# %%
Vandata = data2["last"].apply(pd.Series)
Vandata.insert(4, "Location", "Vancouver")
Vandata.head()
# Out:
#                      time                                            display  \
# arturos-to-go  1633635000                             Howe St & W Cordova St
# bc-taco        1633635000   Rocky Point Spirits - 2805 Murray St, Port Moody
# beavertails    1632708000  Richmond Night Market, 8351 River Rd, Richmond...
# boca-o         1633629600         Jonathan Rogers Park, W 8th Ave, Vancouver
# burgerholic    1633629600                               Jonathan Rogers Park
#
#                 latitude   longitude   Location
# arturos-to-go  49.286466 -123.113481  Vancouver
# bc-taco        49.278868 -122.849935  Vancouver
# beavertails    49.192471 -123.133009  Vancouver
# boca-o         49.263825 -123.108102  Vancouver
# burgerholic    49.264289 -123.107978  Vancouver

# %% [markdown]
# Grab Boston

# %%
url = 'http://data.streetfoodapp.com/1.1/schedule/boston'
data =  requests.get(url).json()
data = df.vendors.apply(pd.Series)
data.head()
# Out:
#                 0 catering delivery_url  \
# ads           NaN      NaN          NaN
# new           NaN      NaN          NaN
# regions       NaN      NaN          NaN
# arturos-to-go NaN     None         None
# babas-house   NaN     None         None
#
#                                                      description  \
# ads                                                          NaN
# new                                                          NaN
# regions                                                      NaN
# arturos-to-go  Arturo's unique recipes are a fusion of Spanis...
# babas-house    Baba's House specialize in Old Fashion Homemad...
#
#                                                description_short  \
# ads                                                          NaN
# new                                                          NaN
# regions                                                      NaN
# arturos-to-go  Authentic, author gourmet Mexican made with th...
# babas-house                                                 None
#
#                                email          facebook     identifier  \
# ads                              NaN               NaN            NaN
# new                              NaN               NaN            NaN
# regions                          NaN               NaN            NaN
# arturos-to-go    info@arturos2go.com  arturosmexico2go  arturos-to-go
# babas-house    maggierabek@yahoo.com              None    babas-house
#
#                                                           images  \
# ads                                                          NaN
# new                                                          NaN
# regions                                                      NaN
# arturos-to-go  {'logo': 'https://cdn.streetfoodapp.com/images...
# babas-house                                                  NaN
#
#                        instagram  ...  open_updated  \
# ads                          NaN  ...           NaN
# new                          NaN  ...           NaN
# regions                      NaN  ...           NaN
# arturos-to-go         arturos2go  ...  1.633977e+09
# babas-house    babashousekitchen  ...           NaN
#
#                                           payment_methods           phone  \
# ads                                                   NaN             NaN
# new                                                   NaN             NaN
# regions                                               NaN             NaN
# arturos-to-go  [cash, credit_card, debit_card, apple_pay]  (604) 202-4043
# babas-house    [cash, credit_card, debit_card, apple_pay]  (778) 838-5059
#
#                promoted   rank  rating     region  takeout_url  \
# ads                 NaN    NaN     NaN        NaN          NaN
# new                 NaN    NaN     NaN        NaN          NaN
# regions             NaN    NaN     NaN        NaN          NaN
# arturos-to-go      True    8.0  1644.0  vancouver         None
# babas-house       False  113.0    15.0  vancouver         None
#
#                        twitter                    url
# ads                        NaN                    NaN
# new                        NaN                    NaN
# regions                    NaN                    NaN
# arturos-to-go  arturomexico2go         arturos2go.com
# babas-house        BabasHouse2  babashousekitchen.com
#
# [5 rows x 23 columns]

# %%
data2 = data[['description', 'name', 'description_short', 'last']].copy()
data2 = data2.dropna()
data2.head()
# Out:
#                                                      description  \
# arturos-to-go  Arturo's unique recipes are a fusion of Spanis...
# bc-taco        Handmade, always fresh. Tacos, burritos, quesa...
# beavertails    Deliciously famous Canadian pastry. Proudly sa...
# boca-o         BOCA'O is the abbreviation of BOCADO, or BITE ...
# burgerholic    BurgerHolic in Vancouver is specializes in mou...
#
#                                          name  \
# arturos-to-go                arturosmexico2go
# bc-taco                               BC TACO
# beavertails    BeaverTails Mobile (Vancouver)
# boca-o                 Boca'o Spain in a bite
# burgerholic                       BurgerHolic
#
#                                                description_short  \
# arturos-to-go  Authentic, author gourmet Mexican made with th...
# bc-taco        Handmade, always fresh. Tacos, burritos, quesa...
# beavertails    Deliciously famous Canadian pastry. Proudly sa...
# boca-o         Boca'O uses premium Spanish and local ingredie...
# burgerholic    Happy to cater your next event Burgerholic.ca@...
#
#                                                             last
# arturos-to-go  {'time': 1633635000, 'display': 'Howe St & W C...
# bc-taco        {'time': 1633635000, 'display': 'Rocky Point S...
# beavertails    {'time': 1632708000, 'display': 'Richmond Nigh...
# boca-o         {'time': 1633629600, 'display': 'Jonathan Roge...
# burgerholic    {'time': 1633629600, 'display': 'Jonathan Roge...

# %%
Bosdata = data2["last"].apply(pd.Series)
Bosdata.insert(4, "Location", "Boston")
Bosdata.head()
# Out:
#                      time                                            display  \
# arturos-to-go  1633635000                             Howe St & W Cordova St
# bc-taco        1633635000   Rocky Point Spirits - 2805 Murray St, Port Moody
# beavertails    1632708000  Richmond Night Market, 8351 River Rd, Richmond...
# boca-o         1633629600         Jonathan Rogers Park, W 8th Ave, Vancouver
# burgerholic    1633629600                               Jonathan Rogers Park
#
#                 latitude   longitude Location
# arturos-to-go  49.286466 -123.113481   Boston
# bc-taco        49.278868 -122.849935   Boston
# beavertails    49.192471 -123.133009   Boston
# boca-o         49.263825 -123.108102   Boston
# burgerholic    49.264289 -123.107978   Boston

# %% [markdown]
# Get the Tallahassee Data

# %%
url = 'http://data.streetfoodapp.com/1.1/schedule/tallahassee'
data =  requests.get(url).json()
data = df.vendors.apply(pd.Series)
data.head()
# Out:
#                 0 catering delivery_url  \
# ads           NaN      NaN          NaN
# new           NaN      NaN          NaN
# regions       NaN      NaN          NaN
# arturos-to-go NaN     None         None
# babas-house   NaN     None         None
#
#                                                      description  \
# ads                                                          NaN
# new                                                          NaN
# regions                                                      NaN
# arturos-to-go  Arturo's unique recipes are a fusion of Spanis...
# babas-house    Baba's House specialize in Old Fashion Homemad...
#
#                                                description_short  \
# ads                                                          NaN
# new                                                          NaN
# regions                                                      NaN
# arturos-to-go  Authentic, author gourmet Mexican made with th...
# babas-house                                                 None
#
#                                email          facebook     identifier  \
# ads                              NaN               NaN            NaN
# new                              NaN               NaN            NaN
# regions                          NaN               NaN            NaN
# arturos-to-go    info@arturos2go.com  arturosmexico2go  arturos-to-go
# babas-house    maggierabek@yahoo.com              None    babas-house
#
#                                                           images  \
# ads                                                          NaN
# new                                                          NaN
# regions                                                      NaN
# arturos-to-go  {'logo': 'https://cdn.streetfoodapp.com/images...
# babas-house                                                  NaN
#
#                        instagram  ...  open_updated  \
# ads                          NaN  ...           NaN
# new                          NaN  ...           NaN
# regions                      NaN  ...           NaN
# arturos-to-go         arturos2go  ...  1.633977e+09
# babas-house    babashousekitchen  ...           NaN
#
#                                           payment_methods           phone  \
# ads                                                   NaN             NaN
# new                                                   NaN             NaN
# regions                                               NaN             NaN
# arturos-to-go  [cash, credit_card, debit_card, apple_pay]  (604) 202-4043
# babas-house    [cash, credit_card, debit_card, apple_pay]  (778) 838-5059
#
#                promoted   rank  rating     region  takeout_url  \
# ads                 NaN    NaN     NaN        NaN          NaN
# new                 NaN    NaN     NaN        NaN          NaN
# regions             NaN    NaN     NaN        NaN          NaN
# arturos-to-go      True    8.0  1644.0  vancouver         None
# babas-house       False  113.0    15.0  vancouver         None
#
#                        twitter                    url
# ads                        NaN                    NaN
# new                        NaN                    NaN
# regions                    NaN                    NaN
# arturos-to-go  arturomexico2go         arturos2go.com
# babas-house        BabasHouse2  babashousekitchen.com
#
# [5 rows x 23 columns]

# %%
data2 = data[['description', 'name', 'description_short', 'last']].copy()
data2 = data2.dropna()
data2.head()
# Out:
#                                                      description  \
# arturos-to-go  Arturo's unique recipes are a fusion of Spanis...
# bc-taco        Handmade, always fresh. Tacos, burritos, quesa...
# beavertails    Deliciously famous Canadian pastry. Proudly sa...
# boca-o         BOCA'O is the abbreviation of BOCADO, or BITE ...
# burgerholic    BurgerHolic in Vancouver is specializes in mou...
#
#                                          name  \
# arturos-to-go                arturosmexico2go
# bc-taco                               BC TACO
# beavertails    BeaverTails Mobile (Vancouver)
# boca-o                 Boca'o Spain in a bite
# burgerholic                       BurgerHolic
#
#                                                description_short  \
# arturos-to-go  Authentic, author gourmet Mexican made with th...
# bc-taco        Handmade, always fresh. Tacos, burritos, quesa...
# beavertails    Deliciously famous Canadian pastry. Proudly sa...
# boca-o         Boca'O uses premium Spanish and local ingredie...
# burgerholic    Happy to cater your next event Burgerholic.ca@...
#
#                                                             last
# arturos-to-go  {'time': 1633635000, 'display': 'Howe St & W C...
# bc-taco        {'time': 1633635000, 'display': 'Rocky Point S...
# beavertails    {'time': 1632708000, 'display': 'Richmond Nigh...
# boca-o         {'time': 1633629600, 'display': 'Jonathan Roge...
# burgerholic    {'time': 1633629600, 'display': 'Jonathan Roge...

# %%
Talladata = data2["last"].apply(pd.Series)
Talladata.insert(4, "Location", "Tallahassee")
Talladata.head()
# Out:
#                      time                                            display  \
# arturos-to-go  1633635000                             Howe St & W Cordova St
# bc-taco        1633635000   Rocky Point Spirits - 2805 Murray St, Port Moody
# beavertails    1632708000  Richmond Night Market, 8351 River Rd, Richmond...
# boca-o         1633629600         Jonathan Rogers Park, W 8th Ave, Vancouver
# burgerholic    1633629600                               Jonathan Rogers Park
#
#                 latitude   longitude     Location
# arturos-to-go  49.286466 -123.113481  Tallahassee
# bc-taco        49.278868 -122.849935  Tallahassee
# beavertails    49.192471 -123.133009  Tallahassee
# boca-o         49.263825 -123.108102  Tallahassee
# burgerholic    49.264289 -123.107978  Tallahassee

# %%
merged_df  = pd.concat([Bosdata,Talladata, Vandata])
merged_df.head()
# Out:
#                      time                                            display  \
# arturos-to-go  1633635000                             Howe St & W Cordova St
# bc-taco        1633635000   Rocky Point Spirits - 2805 Murray St, Port Moody
# beavertails    1632708000  Richmond Night Market, 8351 River Rd, Richmond...
# boca-o         1633629600         Jonathan Rogers Park, W 8th Ave, Vancouver
# burgerholic    1633629600                               Jonathan Rogers Park
#
#                 latitude   longitude Location
# arturos-to-go  49.286466 -123.113481   Boston
# bc-taco        49.278868 -122.849935   Boston
# beavertails    49.192471 -123.133009   Boston
# boca-o         49.263825 -123.108102   Boston
# burgerholic    49.264289 -123.107978   Boston
